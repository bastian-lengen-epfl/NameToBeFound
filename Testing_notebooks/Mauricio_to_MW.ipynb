# %%
import pandas as pd
import numpy as np

# %%
tmp = pd.read_csv('../Data/H1PStars/Cepheids_MW.csv')
Cepheids_MW = pd.DataFrame()
Cepheids_MW['Gal'] = ['MW'] * len(tmp)
Cepheids_MW['logP'] = np.log10(tmp['Period'])
Cepheids_MW['mW'] = tmp['mh']
Cepheids_MW['sig_mW'] = tmp['mh_error']
Cepheids_MW['Fe/H'] = tmp['FE/H']
Cepheids_MW['z'] = 0
Cepheids_MW['V-I'] = np.nan # Don't use K-corrections !!!
Cepheids_MW['pi'] = tmp['Parallax']
Cepheids_MW['sig_pi'] = tmp['Parallax_error']
# Remove Cepheids with no metallicity measurment 
Cepheids_MW = Cepheids_MW[~np.isnan(Cepheids_MW['Fe/H'])].reset_index(drop=True)

# %%
#ADD to those of Riess
'''
tmp = pd.read_csv('../Data/Cepheids_MW.csv', sep=',')
Cepheids_MW = pd.concat([tmp, Cepheids_MW]).reset_index(drop=True)
'''
# Save it
Cepheids_MW.to_csv('../Data/Cepheids_MW.csv',index=False)

# %%
Cepheids_MW
# Out:
#    Gal      logP        mW    sig_mW  Fe/H  z  V-I        pi    sig_pi
# 0   MW  0.592956  7.239755  0.062437  0.15  0  NaN  0.442947  0.010148
# 1   MW  0.640038  7.774535  0.062437  0.09  0  NaN  0.335703  0.010634
# 2   MW  0.687994  7.608335  0.056883  0.02  0  NaN  0.322512  0.010674
# 3   MW  0.721417  5.681213  0.062437  0.19  0  NaN  0.731787  0.011574
# 4   MW  0.730675  6.165182  0.056883  0.09  0  NaN  0.585257  0.012235
# 5   MW  0.739883  4.249141  0.056883  0.04  0  NaN  1.336575  0.009765
# 6   MW  0.771201  7.642653  0.056883  0.12  0  NaN  0.281177  0.010598
# 7   MW  0.793797  5.717240  0.062437  0.15  0  NaN  0.639288  0.010113
# 8   MW  0.800688  4.832108  0.056906  0.07  0  NaN  0.879557  0.010260
# 9   MW  0.828997  3.636512  0.056883  0.08  0  NaN  1.554007  0.009834
# 10  MW  0.878917  5.588822  0.056883  0.11  0  NaN  0.609662  0.010549
# 11  MW  0.903126  5.592998  0.056883 -0.01  0  NaN  0.556510  0.010348
# 12  MW  0.980000  5.742532  0.056883 -0.18  0  NaN  0.496995  0.010386
# 13  MW  0.989188  3.904764  0.056883  0.02  0  NaN  1.073264  0.010550
# 14  MW  1.032868  5.864891  0.056883  0.27  0  NaN  0.420223  0.010825
# 15  MW  1.052648  5.285096  0.056883  0.07  0  NaN  0.513450  0.010184
# 16  MW  1.653145  3.526401  0.054006  0.05  0  NaN  0.424806  0.011677

# %%
A = [1,2,2,3,3,3,4,5,6,7]
N=len(A)-4

# %%
A[N+0]
# Out:
# 4
